# %% [markdown]
# # Week 8: Instructor Led Lab
# Author: Jen Estes \
# Course: BGEN 632 - Introduction to Python \
# Term: Spring 2025 \
# Due Date: April 21st, 2025
#
# This notebook contains code for the inspection and organization of data based on the requirements outlined by Dr. Newton in the BGEN632 Week 8 GitHub repo. While using  the github_teams.csv file, the program builds on Week 7 material by using advanced techniques and piping expressions to sort, order, and filter the data.
#
# ### Notebook Setup
# ----

# %%
# import modules
import os
import numpy as np
import pandas as pd

# %%
# set working directory
os.chdir("/Users/jenestes/Desktop/week8labs/data") 
os.getcwd()  # confirm
# Out:
# '/Users/jenestes/Desktop/week8labs/data'

# %%
# load data and quick inspect
gh_teams = pd.read_csv("github_teams.csv")
gh_teams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   name_h                    608 non-null    object
#  1   Team_type                 608 non-null    object
#  2   Team_size_class           608 non-null    object
#  3   human_members_count       608 non-null    int64
#  4   bot_members_count         608 non-null    int64
#  5   human_work                608 non-null    int64
#  6   work_per_human            608 non-null    float64
#  7   human_gini                608 non-null    float64
#  8   human_Push                608 non-null    int64
#  9   human_IssueComments       608 non-null    int64
#  10  human_PRReviewComment     608 non-null    int64
#  11  human_MergedPR            608 non-null    int64
#  12  bot_work                  608 non-null    int64
#  13  bot_Push                  608 non-null    int64
# ...

# %% [markdown]
# ## Advanced Data Manipulation in Python
# ### Selecting Columns: filter

# %%
# columns `Team_type`, `human_work`, and `work_per_human`
(gh_teams
 .filter(["Team_type", "human_work", "work_per_human"])
)
# Out:
#      Team_type  human_work  work_per_human
# 0    human-bot          66       33.000000
# 1        human          62       31.000000
# 2        human         211       30.142857
# 3    human-bot       14579       62.303419
# 4    human-bot        1625       42.763158
# ..         ...         ...             ...
# 603  human-bot         855      285.000000
# 604      human          63       31.500000
# 605      human          26        5.200000
# 606      human          13        2.600000
# 607  human-bot          57       28.500000
#
# [608 rows x 3 columns]

# %%
# columns that end in the letter `t`
(gh_teams
 .filter(regex = "t$")
)
# Out:
#      human_members_count  bot_members_count  human_PRReviewComment  \
# 0                      2                  1                      4
# 1                      2                  0                      0
# 2                      7                  0                      1
# 3                    234                 12                   1170
# 4                     38                  8                    152
# ..                   ...                ...                    ...
# 603                    3                  1                    373
# 604                    2                  0                      0
# 605                    5                  0                      2
# 606                    5                  0                      1
# 607                    2                  1                      1
#
#      bot_PRReviewComment  issues_count
# 0                      0           8.0
# 1                      0           NaN
# 2                      0          46.0
# ...

# %% [markdown]
# ### Sorting Values

# %%
# sorting descending on columns `Team_size_class`, `human_work`, `work_per_human`
(gh_teams
 .sort_values(by = [ "Team_size_class", "human_work", "work_per_human"], ascending = False)
)
# Out:
#                                             name_h  Team_type Team_size_class  \
# 559  WLaEz_1Nf-YWzHZa8bBgAA/pLoAhZ1cbPT38VYoSdXGmg      human           Small
# 209  eIPosZ68E2LjtaixYK65EQ/0Rp6D1ZR1w4YspfD1H-PfA  human-bot           Small
# 410  pxIFRbeuXsUzHtQB3vDwVA/JlkO4fgLE3bD5QjXcU-0CQ  human-bot           Small
# 268  hXoZRbHPbVxh--funPXSiw/iNU0l_SpKVjGfHOp8vUt8w  human-bot           Small
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# ..                                             ...        ...             ...
# 112  7Xep-tc_sXRqdGZ18-MUog/m4gKCZYLclV3PlKDdogc7w      human           Large
# 564  WMMEJn_D7axJ01w5Xw-8Dw/O8KdDIC1elOLPB08sR2lNw  human-bot           Large
# 165  bxLD_LudiJ8mO7AZa8QgwQ/9LZ8c1ynzo_ohr4eRwcdcg      human           Large
# 562  WMMEJn_D7axJ01w5Xw-8Dw/7F60C3mR08-_sYUM_MNHtA  human-bot           Large
# 292  ilEEnZRNdUqNk7tvvGBo1Q/8xHANrgyHiFV3TuhcqwrpQ      human           Large
#
# ...

# %% [markdown]
# ### Selecting Values: query

# %%
# select `human-bot` teams that have a `bot_members_count` value greater than and equal to 3
(gh_teams
 .query('Team_type == "human-bot" & bot_members_count >= 3')
)
# Out:
#                                            name_h  Team_type Team_size_class  \
# 3   _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4   _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# 89  5Is-_ie16OEGmW1arZm8qg/8UeSk2P76pTG7pPLtxsHTQ  human-bot           Large
#
#     human_members_count  bot_members_count  human_work  work_per_human  \
# 3                   234                 12       14579       62.303419
# 4                    38                  8        1625       42.763158
# 89                   17                  4        7412      436.000000
#
#     human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 3     0.738342        1942                11430                   1170
# 4     0.666607         203                 1270                    152
# 89    0.439621        4182                 1257                   1917
#
#     human_MergedPR  bot_work  bot_Push  bot_IssueComments  \
# ...

# %%
# 'human` teams that are `Large` and have a `human_gini` value greater than and equal to 0.75
(gh_teams
 .query('Team_type == "human" & Team_size_class == "Large" & human_gini >= 0.75')
)
# Out:
#                                             name_h Team_type Team_size_class  \
# 138  ASYGR96YA91p3z7MNKjZCA/IB2pZ8ygcvNnlxUdysjSFA     human           Large
# 285  IiUao8vA_zm_uEIVVLI-Sw/91ya8vlSP8qgwCllH_6BSw     human           Large
# 505  uLHPO58cQefwrJUbyhYOKQ/7YWOP8uDEeKDHQMWKqOoYA     human           Large
# 582  y8Jw59EHVSrsluSuhR5okg/V5vb074jNkzg4YCKforX1Q     human           Large
#
#      human_members_count  bot_members_count  human_work  work_per_human  \
# 138                   12                  0        1655      137.916667
# 285                   25                  0        3599      143.960000
# 505                   48                  0        5748      119.750000
# 582                    8                  0         277       34.625000
#
#      human_gini  human_Push  human_IssueComments  human_PRReviewComment  \
# 138    0.799446         793                  684                    178
# 285    0.863507        1249                 2350                      0
# ...

# %% [markdown]
# ### Finding/Counting Data

# %%
# teams in the `Small` or `Large` category - 147 teams
(gh_teams
 .query('Team_size_class == "Large" | Team_size_class == "Small"')
)
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 601  zPjKmela4b_-cQYzslpJLQ/Y8b87jxGXuKYhNDrcC5AuA      human           Large
# 602  zro7Xud3Xy2f5CjF55l_jA/GChw8QQ_KUPepXGZGDWicQ  human-bot           Small
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %% [markdown]
# There are 428 teams in the Small or Large categories

# %%
# teams  in the `Small` or `Large` category with a `human_gini` value less than and equal to 0.25

(gh_teams
 .query('(Team_size_class == "Large" | Team_size_class == "Small") &  human_gini >= 0.25')
)
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 597  ZDe8CCjo5NLqQVe0wGfFvA/tpINkIPI52aFvMjbNLjJuw      human           Small
# 601  zPjKmela4b_-cQYzslpJLQ/Y8b87jxGXuKYhNDrcC5AuA      human           Large
# 602  zro7Xud3Xy2f5CjF55l_jA/GChw8QQ_KUPepXGZGDWicQ  human-bot           Small
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
#
# ...

# %% [markdown]
# There are 342 teams in the Small or Large categories with a `human_gini` value less than and equal to 0.25.

# %%
# `human` teams in the `Medium` category
(gh_teams
 .query('Team_type == "human" & Team_size_class == "Medium" ')
)
# Out:
#                                             name_h Team_type Team_size_class  \
# 8    _yD8m1Di58SxsWVtbFs8qA/-UAPBK3VxONRihRwJV8rbQ     human          Medium
# 20   0_i2yUqqQXqOqRd8kyC-pQ/yrrxKjGqkqQ9S6ELsPmmCw     human          Medium
# 46   2B7IxtFwGYG8romCC5DROw/JWHcllSwE7P2HpW1xjcQ6Q     human          Medium
# 47   2bL_hc3RIUujEgCYopaKRQ/lj0G1E2S6gy_t3ZRgMccyg     human          Medium
# 53   3fa6t1_rA76z0ctbksVa4g/GfIwhFCOo1NjJHOk2LzVRQ     human          Medium
# ..                                             ...       ...             ...
# 574  xUHitt6_tbQU1U9fKA_JBg/FijNnq1-psXPKK1HqWOjag     human          Medium
# 584  yLydVqZyxRsGHiWGJ3t0rg/LBTLKUJrYdX511Nj-t1U-A     human          Medium
# 600  ZPbZUFullnQ00GjBX1RaUQ/fR24eYhOcMGsDUKZIYFXeg     human          Medium
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ     human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg     human          Medium
#
# ...

# %% [markdown]
# There are 96 `human` teams in the `Medium` category.

# %% [markdown]
# ## New DataFrame

# %%
# new DataFrame with `Team_size_class` and `work_per_human`
gh_teams2 = (gh_teams
             .filter(["Team_size_class","work_per_human"])
                ) 
gh_teams2 # checking output - success!
# Out:
#     Team_size_class  work_per_human
# 0             Small       33.000000
# 1             Small       31.000000
# 2             Large       30.142857
# 3             Large       62.303419
# 4             Large       42.763158
# ..              ...             ...
# 603           Small      285.000000
# 604           Small       31.500000
# 605          Medium        5.200000
# 606          Medium        2.600000
# 607           Small       28.500000
#
# [608 rows x 2 columns]

# %% [markdown]
# ### Renaming columns : rename()

# %%
gh_teams3 = (gh_teams
             .rename({'human_gini':'work_inequality',
              'eval_survival_day_median':'issue_resolution_time'})
            )
gh_teams3
# Out:
#                                             name_h  Team_type Team_size_class  \
# 0    _1bqaxzCk0sfQaunsjeViQ/RCEZ3CASdLXbstu9y2JQ7Q  human-bot           Small
# 1    _9o07rGiC7DFyi-zm91Q0g/VOgMsrjYEwFAq0BY8kHqGQ      human           Small
# 2    _DzK53uaZXnAX3WcC0W28g/Epc4QWw5PNBQIIdvopEHDA      human           Large
# 3    _l5u7I5p4thtW5SjR_9_4w/aZNCdVXta7fh7eCMzZP1CA  human-bot           Large
# 4    _l5u7I5p4thtW5SjR_9_4w/m_FpD7PKQHqVXHn2bh7u2g  human-bot           Large
# ..                                             ...        ...             ...
# 603  zTj5tlMWgotzJmQl7BP8wQ/iQ914_smScbUO8BI9JlE6A  human-bot           Small
# 604  zUBexdmYylGGpxiebXm6gg/sJXD2kulWzU35ijdY3SnBQ      human           Small
# 605  zVSBi-iRKCzLiqFwVt6hbg/8SfUBIOeWUjDoQxeUCX7wQ      human          Medium
# 606  zVSBi-iRKCzLiqFwVt6hbg/fm_lDWwc8Uu-aZ24BjUNZg      human          Medium
# 607  ZX09uvu0z_JVPVI-XrPniQ/pxiuGX_R6QI2Euvx2GFIFw  human-bot           Small
#
# ...

# %% [markdown]
# ## Lab Complete!
